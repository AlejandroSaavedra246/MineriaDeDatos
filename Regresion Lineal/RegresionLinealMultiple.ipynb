# %% [markdown]
# INTRODUCCIÓN
#
# Hare uso de la regresion lineal multiple para trabajar un documento de vehiculos procesados ya que esta trabaja para evaluar las relaciones entre un destino continuo y los predictores que en este caso serian las variables independientes y la variable continua.

# %%
#importamos las librerias
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/gdrive')

ruta = "/gdrive/MyDrive/Regresion Lineal/vehiculos_procesado.csv"
data = pd.read_csv(ruta, encoding ="latin1")
# Out:
# Mounted at /gdrive

# %% [markdown]
# ver registros que tiene

# %%
data.shape
# Out:
# (35539, 13)

# %% [markdown]
# verificar el tipo de datos que tiene las tablas

# %%
data.dtypes
# Out:
# fabricante             object
# modelo                 object
# year                    int64
# desplazamiento        float64
# cilindros             float64
# transmision            object
# traccion               object
# clase                  object
# combustible            object
# consumo                 int64
# co2                   float64
# consumo_std           float64
# desplazamiento_std    float64
# dtype: object

# %% [markdown]
# Estas son las columnas que utilizaremos ya que contienen valores numericos.

# %%
data[["co2", "cilindros", "desplazamiento", "consumo"]].describe()
# Out:
#                 co2     cilindros  desplazamiento       consumo
# count  35539.000000  35539.000000    35539.000000  35539.000000
# mean     470.607342      5.727426        3.308585     19.863277
# std      104.425820      1.705600        1.318233      4.383492
# min      169.000000      2.000000        1.000000     10.000000
# 25%      396.000000      4.000000        2.200000     17.000000
# 50%      465.000000      6.000000        3.000000     19.000000
# 75%      525.000000      6.000000        4.300000     23.000000
# max      782.000000     12.000000        8.400000     33.000000

# %%
#Agregamos la tabla que nos va a mostrar la correlacion que hay entre cada variable

import pandas as pd
import seaborn as sns
import matplotlib as plt

#La matriz de correlación
matriz_correlacion = data.corr().round(2)
matriz_correlacion #Imprimir la matriz de correlación con dos cifras después del cero

#El mapa de calor
sns.heatmap(data=matriz_correlacion, annot=True, cmap="YlGnBu")
# Out:
# <ipython-input-9-9c2ca3444a10>:9: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matriz_correlacion = data.corr().round(2)
# <Axes: >

# %%
sns.pairplot(data, x_vars=['cilindros','desplazamiento'], y_vars='co2', size=8, aspect=0.8,kind = 'reg')
#aqui solo se agrego  la muestra de las graficas
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Conclusion**
#
# En la regresion lineal multiple podemos observar que la variable del Co2 es la variable con mas relacion y junto a la de desplazamiento y cilindros podemos caulcular o predecir de cierta forma el consumo que tiene el automovil.
